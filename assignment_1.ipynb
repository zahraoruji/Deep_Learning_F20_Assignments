# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import sklearn
import torch
import tensorflow as tf

# %%
print("Scikit-learn Version: ", sklearn.__version__)
print("TensorFlow Version: ", tf.__version__)
print("PyTorch Version: ", torch.__version__)
# Out:
# Scikit-learn Version:  0.23.1
# TensorFlow Version:  2.2.0
# PyTorch Version:  1.5.0+cpu

# %%
start_time = time.time()
data = {'a': np.arange(500),
        'c': np.random.randint(0, 500, 500),
        'd': np.random.randn(500)}
data['b'] = data['a'] + 5 * np.random.randn(500)
data['d'] = np.abs(data['d']) * 100
plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('A')
plt.ylabel('B')
plt.show()
df = pd.DataFrame(np.random.randn(10, 5)) 
print(df)
j=np.pi
for i in range(100000000):
  j+=j    
print("\n-> Execution Time = %s in Seconds <-" % (time.time() - start_time))
# Out:
#           0         1         2         3         4
# 0 -0.577068  0.479004  0.946338 -0.649758  0.053998
# 1  0.919408  0.959081  0.481726  0.182925 -2.424699
# 2  0.979889  1.059100  1.035260  1.058790 -1.601349
# 3  0.369240  1.406672  2.353859 -1.337030  2.350015
# 4 -1.079860 -0.876606 -0.770935  0.569812  0.051491
# 5 -0.165049  0.344461  0.457132 -0.580673 -0.044617
# 6 -1.202241  0.717842 -0.704742  0.671918 -0.877492
# 7 -1.677085 -0.630452  1.584431 -0.045989  0.495082
# 8 -0.240432  1.296487 -0.230066  0.517350 -1.577673
# 9 -0.127694  0.529828  1.929238  1.161417 -0.717494
#
# -> Execution Time = 11.363653659820557 in Seconds <-
