# %% [markdown]
# Assignment Set 1 by [zahraoruji] for [Deep Learing/Applied Machine Learning] Course at Data Science Center, SBU

# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import sklearn
import torch
import tensorflow as tf

# %%
print("Scikit-learn Version: ", sklearn.__version__)
print("TensorFlow Version: ", tf.__version__)
print("PyTorch Version: ", torch.__version__)
# Out:
# Scikit-learn Version:  0.23.1
# TensorFlow Version:  2.2.0
# PyTorch Version:  1.5.0+cpu

# %%
start_time = time.time()
data = {'a': np.arange(500),
        'c': np.random.randint(0, 500, 500),
        'd': np.random.randn(500)}
data['b'] = data['a'] + 5 * np.random.randn(500)
data['d'] = np.abs(data['d']) * 100
plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('A')
plt.ylabel('B')
plt.show()
df = pd.DataFrame(np.random.randn(10, 5)) 
print(df)
j=np.pi
for i in range(100000000):
  j+=j    
print("\n-> Execution Time = %s in Seconds <-" % (time.time() - start_time))
# Out:
#           0         1         2         3         4
# 0  0.009394 -0.378063 -1.311902 -1.120362  0.076591
# 1  1.014274 -2.262923  0.091515  1.881897  0.822915
# 2  0.767097  2.079020 -0.996618  1.390531 -0.281035
# 3 -0.882245 -1.541999 -0.763854  1.016140 -1.497051
# 4  0.558799 -0.271811  0.222097 -1.843090 -1.230470
# 5 -1.612667 -0.044304 -0.656373 -1.099466 -0.538718
# 6 -0.829538 -0.789031  0.091424 -1.229664 -0.096905
# 7 -0.368953 -0.325125 -0.758777 -1.279429 -0.184105
# 8 -0.759674  1.158672 -0.320197 -0.413942  1.079327
# 9  0.198946  0.388805 -1.505917  0.599074 -0.808171
#
# -> Execution Time = 29.339624404907227 in Seconds <-
