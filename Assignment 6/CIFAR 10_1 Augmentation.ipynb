# %% [markdown]
# # Assignment Set 2
# by Zahraoruji for Deep Learing Course at Data Science Center, SBU

# %%
import torch
import torchvision
import numpy
import os
import torch.utils.data as datautils
import matplotlib.pyplot as plt
import torch.nn as to_nn
import torch.nn.functional as to_f
import torch.optim as optim
from torch.autograd import Variable
from torchsummary import summary
import torchvision.transforms as transforms

# %%
# !pip install torchsummary
# Out:
# WARNING: You are using pip version 20.2.3; however, version 20.2.4 is available.
# Requirement already satisfied: torchsummary in c:\users\negar\appdata\local\programs\python\python38\lib\site-packages (1.5.1)
# You should consider upgrading via the 'c:\users\negar\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# # Data Augmentation without Regularization

# %%
first_train_transform = transforms.Compose(
                [transforms.RandomHorizontalFlip(),
                 transforms.RandomCrop(size=[32,32], padding=4),
                 transforms.ToTensor()])

# load training and test set
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
cifar10_training_set = torchvision.datasets.CIFAR10(root='./dataset_CIFAR10', train=True, transform=image_transforms,
                                                    download=True)
cifar10_test_set = torchvision.datasets.CIFAR10(root='./dataset_CIFAR10', train=False, transform=image_transforms,
                                                    download=True)
trainingset_loader = datautils.DataLoader(dataset=cifar10_training_set, batch_size=4, shuffle=True, num_workers=2)
testset_loader = datautils.DataLoader(dataset=cifar10_test_set, batch_size=4, shuffle=True, num_workers=2)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
def matplotlib_imshow(img_tensor, title=None):
    """
    Get and image in tensor form and display it.
    :param img_tensor:
    :return:
    """
    device = torch.device("cpu")
    img_tensor_cpu = img_tensor.to(device)
 
    std = 0.5
    mean = 0.5
 
    img_tensor = std * img_tensor_cpu + mean
    # convert tensor to numpy
    img = img_tensor.numpy()
    # in pytorch image is (3, H, W)
    # normal form is (H, W, 3)
    img = img.transpose(1, 2, 0)
    plt.figure()
    plt.imshow(img)
    if title is not None:
        plt.title(title)

# %%
class ConvNet(to_nn.Module):
 
    # constructor of model
    def __init__(self):
        # constructor of parent class
        super(ConvNet, self).__init__()
        # learnable parameter of model (convolution and fully connected layers)
        self.conv1 = to_nn.Conv2d(in_channels=3, out_channels=9, kernel_size=(5, 5))
        self.conv2 = to_nn.Conv2d(in_channels=9, out_channels=18, kernel_size=(3, 3))
        self.fc1 = to_nn.Linear(in_features=18 * 6 * 6, out_features=100)
        self.fc2 = to_nn.Linear(in_features=100, out_features=40)
        self.fc3 = to_nn.Linear(in_features=40, out_features=10)
 
    # feedforward
    def forward(self, input):
        # convolutional layer 1
        out = self.conv1(input)
        # pooling kernel size(2,2) and relu non linearity
        out = to_f.max_pool2d(to_f.relu(out), (2, 2))
        # convolutional layer 2
        out = self.conv2(out)
        # pooling kernel size(2,2) and relu non linearity
        out = to_f.max_pool2d(to_f.relu(out), (2, 2))
        # flatten
        out = out.view(-1, 18 * 6 * 6)
        # fully connected 1 with relu non linearity
        out = to_f.relu(self.fc1(out))
        # fully connected 2 with relu non linearity
        out = to_f.relu(self.fc2(out))
        # fully connected 3
        out = self.fc3(out)
        return out

# %%
net = ConvNet()

# %%
criterion = to_nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

# %%
LAMBDA = 0.009

for epoch in range(10):
 
    # loss of epoch
    running_loss = 0.0
 
    # iterate over all batches
    for i, data in enumerate(trainingset_loader, 0):
 
        images, labels = data
 
        # makes all gradients zero
        optimizer.zero_grad()
 
        # feedforward
        images = images
        output = net(images)
 
        # loss
        labels = labels
        loss = criterion(output, labels)
    
        
        # backpropagation
        loss.backward()
 
        # update parameters
        optimizer.step()
 
        running_loss += loss.item()
 
        if i % 1000 == 999:
            print('epoch {}, mini-batch {}, loss {}'.format(epoch, i + 1, running_loss/1000.0))
            running_loss = 0.0
 
print('Training Phase is done.')
# Out:
# epoch 0, mini-batch 1000, loss 2.2965765273571015
# epoch 0, mini-batch 2000, loss 2.099556497216225
# epoch 0, mini-batch 3000, loss 1.9103784903287888
# epoch 0, mini-batch 4000, loss 1.7702206750512124
# epoch 0, mini-batch 5000, loss 1.657741453796625
# epoch 0, mini-batch 6000, loss 1.600678132712841
# epoch 0, mini-batch 7000, loss 1.5209916532337666
# epoch 0, mini-batch 8000, loss 1.4944425976276399
# epoch 0, mini-batch 9000, loss 1.4966239856332542
# epoch 0, mini-batch 10000, loss 1.4225530307292937
# epoch 0, mini-batch 11000, loss 1.4091745836436749
# epoch 0, mini-batch 12000, loss 1.3775607386231423
# epoch 1, mini-batch 1000, loss 1.3184301749020815
# epoch 1, mini-batch 2000, loss 1.3206395483613014
# epoch 1, mini-batch 3000, loss 1.2828480324298144
# epoch 1, mini-batch 4000, loss 1.287690644800663
# epoch 1, mini-batch 5000, loss 1.2442980882376433
# epoch 1, mini-batch 6000, loss 1.2263415278419851
# epoch 1, mini-batch 7000, loss 1.2379217710196972
# epoch 1, mini-batch 8000, loss 1.2262393057867884
# epoch 1, mini-batch 9000, loss 1.188332511484623
# epoch 1, mini-batch 10000, loss 1.2204736799448728
# epoch 1, mini-batch 11000, loss 1.1925230564661324
# epoch 1, mini-batch 12000, loss 1.1660851811878383
# epoch 2, mini-batch 1000, loss 1.0815539471395315
# epoch 2, mini-batch 2000, loss 1.0895353678390385
# epoch 2, mini-batch 3000, loss 1.0988296261765063
# epoch 2, mini-batch 4000, loss 1.0962977357804775
# epoch 2, mini-batch 5000, loss 1.114292555835098
# epoch 2, mini-batch 6000, loss 1.0791494407504798
# epoch 2, mini-batch 7000, loss 1.0881926171183587
# epoch 2, mini-batch 8000, loss 1.1086079886928202
# epoch 2, mini-batch 9000, loss 1.0968005188778043
# epoch 2, mini-batch 10000, loss 1.0653899113424123
# epoch 2, mini-batch 11000, loss 1.0613493713401259
# epoch 2, mini-batch 12000, loss 1.0517924178391695
# epoch 3, mini-batch 1000, loss 0.9678106236262247
# epoch 3, mini-batch 2000, loss 0.9586930249147118
# epoch 3, mini-batch 3000, loss 0.9664445191510022
# epoch 3, mini-batch 4000, loss 0.9503036471251398
# epoch 3, mini-batch 5000, loss 0.9845824917480349
# epoch 3, mini-batch 6000, loss 0.9805542110204697
# epoch 3, mini-batch 7000, loss 1.0314716624096036
# epoch 3, mini-batch 8000, loss 0.9897096023801715
# epoch 3, mini-batch 9000, loss 0.9872364447154105
# epoch 3, mini-batch 10000, loss 1.00332170740515
# epoch 3, mini-batch 11000, loss 1.0067124193683266
# epoch 3, mini-batch 12000, loss 0.9906558459699154
# epoch 4, mini-batch 1000, loss 0.8988220330290496
# epoch 4, mini-batch 2000, loss 0.8607712664410938
# epoch 4, mini-batch 3000, loss 0.8837257449552417
# epoch 4, mini-batch 4000, loss 0.8958903337102383
# epoch 4, mini-batch 5000, loss 0.8842980484813452
# epoch 4, mini-batch 6000, loss 0.9245435448437929
# epoch 4, mini-batch 7000, loss 0.9307259613219648
# epoch 4, mini-batch 8000, loss 0.9288811297584325
# epoch 4, mini-batch 9000, loss 0.9024369688592851
# epoch 4, mini-batch 10000, loss 0.8992590081403032
# epoch 4, mini-batch 11000, loss 0.9287467672489583
# epoch 4, mini-batch 12000, loss 0.934109352413565
# epoch 5, mini-batch 1000, loss 0.808697814496234
# epoch 5, mini-batch 2000, loss 0.8050009174216539
# epoch 5, mini-batch 3000, loss 0.8356378329880536
# epoch 5, mini-batch 4000, loss 0.8493950136592612
# epoch 5, mini-batch 5000, loss 0.838712690718472
# epoch 5, mini-batch 6000, loss 0.8309361091963947
# epoch 5, mini-batch 7000, loss 0.8770463590119034
# epoch 5, mini-batch 8000, loss 0.8424729138370604
# epoch 5, mini-batch 9000, loss 0.8589396974486299
# epoch 5, mini-batch 10000, loss 0.867188839004375
# epoch 5, mini-batch 11000, loss 0.8927740909345449
# epoch 5, mini-batch 12000, loss 0.8506144150979817
# epoch 6, mini-batch 1000, loss 0.7546468634080374
# epoch 6, mini-batch 2000, loss 0.7730004079341889
# epoch 6, mini-batch 3000, loss 0.7545091515351087
# epoch 6, mini-batch 4000, loss 0.802446541974321
# epoch 6, mini-batch 5000, loss 0.7928276727679185
# epoch 6, mini-batch 6000, loss 0.8219860385810025
# epoch 6, mini-batch 7000, loss 0.8108797987708822
# epoch 6, mini-batch 8000, loss 0.8175387985841371
# epoch 6, mini-batch 9000, loss 0.8232400821708142
# epoch 6, mini-batch 10000, loss 0.804365472568199
# epoch 6, mini-batch 11000, loss 0.8438445693794638
# epoch 6, mini-batch 12000, loss 0.8267440164163709
# epoch 7, mini-batch 1000, loss 0.709238478731364
# epoch 7, mini-batch 2000, loss 0.719427462434629
# epoch 7, mini-batch 3000, loss 0.7281993810487911
# epoch 7, mini-batch 4000, loss 0.7454719125851988
# epoch 7, mini-batch 5000, loss 0.7885221210708842
# epoch 7, mini-batch 6000, loss 0.7712933344300836
# epoch 7, mini-batch 7000, loss 0.7728629004694522
# epoch 7, mini-batch 8000, loss 0.7683379437876865
# epoch 7, mini-batch 9000, loss 0.7475420937268064
# epoch 7, mini-batch 10000, loss 0.7760507519361564
# epoch 7, mini-batch 11000, loss 0.7946611673496664
# epoch 7, mini-batch 12000, loss 0.7967787979543209
# epoch 8, mini-batch 1000, loss 0.6536584801014979
# epoch 8, mini-batch 2000, loss 0.6850064332913607
# epoch 8, mini-batch 3000, loss 0.7044096562261694
# epoch 8, mini-batch 4000, loss 0.719705427022418
# epoch 8, mini-batch 5000, loss 0.7370735034854151
# epoch 8, mini-batch 6000, loss 0.7208029026668519
# epoch 8, mini-batch 7000, loss 0.7291228926470503
# epoch 8, mini-batch 8000, loss 0.7190881070499309
# epoch 8, mini-batch 9000, loss 0.7397466368651949
# epoch 8, mini-batch 10000, loss 0.7435693706339225
# epoch 8, mini-batch 11000, loss 0.764229973978363
# epoch 8, mini-batch 12000, loss 0.7727587448488921
# epoch 9, mini-batch 1000, loss 0.6185367038203403
# epoch 9, mini-batch 2000, loss 0.6487528825030895
# epoch 9, mini-batch 3000, loss 0.6310883001204056
# epoch 9, mini-batch 4000, loss 0.677593161926372
# epoch 9, mini-batch 5000, loss 0.6801309590542224
# epoch 9, mini-batch 6000, loss 0.7377347660972737
# epoch 9, mini-batch 7000, loss 0.677243577905465
# epoch 9, mini-batch 8000, loss 0.7040986795714708
# epoch 9, mini-batch 9000, loss 0.7312005218015983
# epoch 9, mini-batch 10000, loss 0.7025423811548389
# epoch 9, mini-batch 11000, loss 0.7520560139601584
# epoch 9, mini-batch 12000, loss 0.6990281787477434
# Training Phase is done.

# %%
# show qualitative result of training
data_iter = iter(testset_loader)
for i in range(3):
    images, labels_ground_truth = data_iter.next()
    images = images
    labels_ground_truth = labels_ground_truth
    outputs = net(images)
    _, predicted = torch.max(outputs, dim=1)
    matplotlib_imshow(img_tensor=torchvision.utils.make_grid(images), title=['predicted: '+classes[i.item()] for i in predicted])

correct = 0
total = 0
with torch.no_grad():
    for data in testset_loader:
        images, ground_truth_labels = data
        images = images
        ground_truth_labels = ground_truth_labels
        outputs = net(images)
        _, predicted = torch.max(outputs, dim=1)
        total += ground_truth_labels.size(0)
        correct += (ground_truth_labels==predicted).sum().item()
print('Accuracy on test set is: {}%'.format(correct/total * 100))
 
# accuracy of each class in test set
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in testset_loader:
        images, labels = data
        images = images
        labels = labels
        outputs = net(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1
for i in range(10):
    print('Accuracy of {}: {}%'.format(classes[i], 100 * class_correct[i] / class_total[i]))
plt.show()
# Out:
# Accuracy on test set is: 66.09%
# Accuracy of plane: 65.2%
# Accuracy of car: 78.7%
# Accuracy of bird: 61.5%
# Accuracy of cat: 46.9%
# Accuracy of deer: 68.1%
# Accuracy of dog: 55.2%
# Accuracy of frog: 66.5%
# Accuracy of horse: 69.5%
# Accuracy of ship: 78.5%
# Accuracy of truck: 70.8%

# %% [markdown]
# # Augmentation with L2 Regularization

# %%
LAMBDA = 0.009

for epoch in range(10):
 
    # loss of epoch
    running_loss = 0.0
 
    # iterate over all batches
    for i, data in enumerate(trainingset_loader, 0):
 
        images, labels = data
 
        # makes all gradients zero
        optimizer.zero_grad()
 
        # feedforward
        images = images
        output = net(images)
 
        # loss
        labels = labels
        loss = criterion(output, labels)
        
        #L1 regularization
        
        l2_regularization = torch.tensor(0).long()
        for param in net.parameters():
            l2_regularization += torch.norm(param, 1).long()
            
        loss += LAMBDA * l2_regularization
        
        
 
        # backpropagation
        loss.backward()
 
        # update parameters
        optimizer.step()
 
        running_loss += loss.item()
 
        if i % 1000 == 999:
            print('epoch {}, mini-batch {}, loss {}'.format(epoch, i + 1, running_loss/1000.0))
            running_loss = 0.0
 
print('Training Phase is done.')
# Out:
# epoch 0, mini-batch 1000, loss 50.0502829322815
# epoch 0, mini-batch 2000, loss 50.32882347869873
# epoch 0, mini-batch 3000, loss 50.60645602798462
# epoch 0, mini-batch 4000, loss 50.83255902481079
# epoch 0, mini-batch 5000, loss 51.0711215057373
# epoch 0, mini-batch 6000, loss 51.247210472106936
# epoch 0, mini-batch 7000, loss 51.516506038665774
# epoch 0, mini-batch 8000, loss 51.72981198120117
# epoch 0, mini-batch 9000, loss 51.937417747497555
# epoch 0, mini-batch 10000, loss 52.15121949005127
# epoch 0, mini-batch 11000, loss 52.35608354949951
# epoch 0, mini-batch 12000, loss 52.55092039871216
# epoch 1, mini-batch 1000, loss 52.779504062652585
# epoch 1, mini-batch 2000, loss 53.03905265045166
# epoch 1, mini-batch 3000, loss 53.31524200820923
# epoch 1, mini-batch 4000, loss 53.56227290725708
# epoch 1, mini-batch 5000, loss 53.84968101119995
# epoch 1, mini-batch 6000, loss 54.03776226806641
# epoch 1, mini-batch 7000, loss 54.31322337341309
# epoch 1, mini-batch 8000, loss 54.46873623657227
# epoch 1, mini-batch 9000, loss 54.65190187835693
# epoch 1, mini-batch 10000, loss 54.86070716094971
# epoch 1, mini-batch 11000, loss 55.06901552581787
# epoch 1, mini-batch 12000, loss 55.274576564788816
# epoch 2, mini-batch 1000, loss 55.46822426223755
# epoch 2, mini-batch 2000, loss 55.71516216659546
# epoch 2, mini-batch 3000, loss 55.981176433563235
# epoch 2, mini-batch 4000, loss 56.23531642913818
# epoch 2, mini-batch 5000, loss 56.46710305404663
# epoch 2, mini-batch 6000, loss 56.67308755874634
# epoch 2, mini-batch 7000, loss 56.89985149383545
# epoch 2, mini-batch 8000, loss 57.10349708938599
# epoch 2, mini-batch 9000, loss 57.348922653198244
# epoch 2, mini-batch 10000, loss 57.53933089828491
# epoch 2, mini-batch 11000, loss 57.762460750579834
# epoch 2, mini-batch 12000, loss 57.963247077941894
# epoch 3, mini-batch 1000, loss 58.15921983718872
# epoch 3, mini-batch 2000, loss 58.4033840713501
# epoch 3, mini-batch 3000, loss 58.634675037384035
# epoch 3, mini-batch 4000, loss 58.83745400238037
# epoch 3, mini-batch 5000, loss 59.080002185821535
# epoch 3, mini-batch 6000, loss 59.242408573150634
# epoch 3, mini-batch 7000, loss 59.51055321884155
# epoch 3, mini-batch 8000, loss 59.73482989501953
# epoch 3, mini-batch 9000, loss 59.945845226287844
# epoch 3, mini-batch 10000, loss 60.15488039779663
# epoch 3, mini-batch 11000, loss 60.37669836807251
# epoch 3, mini-batch 12000, loss 60.53860622787476
# epoch 4, mini-batch 1000, loss 60.725424606323244
# epoch 4, mini-batch 2000, loss 60.97925361251831
# epoch 4, mini-batch 3000, loss 61.21363489532471
# epoch 4, mini-batch 4000, loss 61.4309310798645
# epoch 4, mini-batch 5000, loss 61.638766593933106
# epoch 4, mini-batch 6000, loss 61.86236499786377
# epoch 4, mini-batch 7000, loss 62.057260837554935
# epoch 4, mini-batch 8000, loss 62.269044975280764
# epoch 4, mini-batch 9000, loss 62.427043292999265
# epoch 4, mini-batch 10000, loss 62.64813972854614
# epoch 4, mini-batch 11000, loss 62.8369302482605
# epoch 4, mini-batch 12000, loss 63.030923191070556
# epoch 5, mini-batch 1000, loss 63.16176449203491
# epoch 5, mini-batch 2000, loss 63.443757274627686
# epoch 5, mini-batch 3000, loss 63.65303776168823
# epoch 5, mini-batch 4000, loss 63.839193870544435
# epoch 5, mini-batch 5000, loss 64.07399293899536
# epoch 5, mini-batch 6000, loss 64.26272976684571
# epoch 5, mini-batch 7000, loss 64.49216468048095
# epoch 5, mini-batch 8000, loss 64.68695648193359
# epoch 5, mini-batch 9000, loss 64.85584263610839
# epoch 5, mini-batch 10000, loss 65.0274761352539
# epoch 5, mini-batch 11000, loss 65.21676625823974
# epoch 5, mini-batch 12000, loss 65.40115046691895
# epoch 6, mini-batch 1000, loss 65.53693614196777
# epoch 6, mini-batch 2000, loss 65.77841065216064
# epoch 6, mini-batch 3000, loss 66.02946301269532
# epoch 6, mini-batch 4000, loss 66.18656015014649
# epoch 6, mini-batch 5000, loss 66.41374036407471
# epoch 6, mini-batch 6000, loss 66.60976796722412
# epoch 6, mini-batch 7000, loss 66.78330562591553
# epoch 6, mini-batch 8000, loss 67.00864263153076
# epoch 6, mini-batch 9000, loss 67.15308811950683
# epoch 6, mini-batch 10000, loss 67.37407574462891
# epoch 6, mini-batch 11000, loss 67.54287289428711
# epoch 6, mini-batch 12000, loss 67.7548060913086
# epoch 7, mini-batch 1000, loss 67.8508364868164
# epoch 7, mini-batch 2000, loss 68.10554415130615
# epoch 7, mini-batch 3000, loss 68.30515579223633
# epoch 7, mini-batch 4000, loss 68.50699340820313
# epoch 7, mini-batch 5000, loss 68.74168936157227
# epoch 7, mini-batch 6000, loss 68.91332257843018
# epoch 7, mini-batch 7000, loss 69.13857509613037
# epoch 7, mini-batch 8000, loss 69.32823939514161
# epoch 7, mini-batch 9000, loss 69.50144485473633
# epoch 7, mini-batch 10000, loss 69.68159824371338
# epoch 7, mini-batch 11000, loss 69.86031513214111
# epoch 7, mini-batch 12000, loss 70.0445082397461
# epoch 8, mini-batch 1000, loss 70.18919658660889
# epoch 8, mini-batch 2000, loss 70.44053061676026
# epoch 8, mini-batch 3000, loss 70.59890866088867
# epoch 8, mini-batch 4000, loss 70.80575108337402
# epoch 8, mini-batch 5000, loss 71.03955135345458
# epoch 8, mini-batch 6000, loss 71.1860034790039
# epoch 8, mini-batch 7000, loss 71.40564750671386
# epoch 8, mini-batch 8000, loss 71.60177926635743
# epoch 8, mini-batch 9000, loss 71.78239500427246
# epoch 8, mini-batch 10000, loss 71.99149208068847
# epoch 8, mini-batch 11000, loss 72.13354237365722
# epoch 8, mini-batch 12000, loss 72.2578818283081
# epoch 9, mini-batch 1000, loss 72.4044139175415
# epoch 9, mini-batch 2000, loss 72.61091032409668
# epoch 9, mini-batch 3000, loss 72.80164077758789
# epoch 9, mini-batch 4000, loss 73.05269138336182
# epoch 9, mini-batch 5000, loss 73.18619513702393
# epoch 9, mini-batch 6000, loss 73.39448544311523
# epoch 9, mini-batch 7000, loss 73.54559449005127
# epoch 9, mini-batch 8000, loss 73.78230374145508
# epoch 9, mini-batch 9000, loss 73.92269230651856
# epoch 9, mini-batch 10000, loss 74.07212573242188
# epoch 9, mini-batch 11000, loss 74.30819369506835
# epoch 9, mini-batch 12000, loss 74.46688050079345
# Training Phase is done.

# %%
# show qualitative result of training
data_iter = iter(testset_loader)
for i in range(3):
    images, labels_ground_truth = data_iter.next()
    images = images
    labels_ground_truth = labels_ground_truth
    outputs = net(images)
    _, predicted = torch.max(outputs, dim=1)
    matplotlib_imshow(img_tensor=torchvision.utils.make_grid(images), title=['predicted: '+classes[i.item()] for i in predicted])

correct = 0
total = 0
with torch.no_grad():
    for data in testset_loader:
        images, ground_truth_labels = data
        images = images
        ground_truth_labels = ground_truth_labels
        outputs = net(images)
        _, predicted = torch.max(outputs, dim=1)
        total += ground_truth_labels.size(0)
        correct += (ground_truth_labels==predicted).sum().item()
print('Accuracy on test set is: {}%'.format(correct/total * 100))
 
# accuracy of each class in test set
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in testset_loader:
        images, labels = data
        images = images
        labels = labels
        outputs = net(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1
for i in range(10):
    print('Accuracy of {}: {}%'.format(classes[i], 100 * class_correct[i] / class_total[i]))
plt.show()
# Out:
# Accuracy on test set is: 63.32%
# Accuracy of plane: 64.4%
# Accuracy of car: 78.0%
# Accuracy of bird: 41.5%
# Accuracy of cat: 67.1%
# Accuracy of deer: 53.4%
# Accuracy of dog: 39.5%
# Accuracy of frog: 71.2%
# Accuracy of horse: 65.8%
# Accuracy of ship: 78.5%
# Accuracy of truck: 73.8%
