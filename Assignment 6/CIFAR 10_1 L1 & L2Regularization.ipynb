# %% [markdown]
# # Assignment Set 2
# by Zahraoruji for Deep Learing Course at Data Science Center, SBU

# %%
import torch
import torchvision
import numpy
import os
import torch.utils.data as datautils
import matplotlib.pyplot as plt
import torch.nn as to_nn
import torch.nn.functional as to_f
import torch.optim as optim
from torch.autograd import Variable
from torchsummary import summary
import torchvision.transforms as transforms

# %%
# !pip install torchsummary
# Out:
# WARNING: You are using pip version 20.2.3; however, version 20.2.4 is available.
# Requirement already satisfied: torchsummary in c:\users\negar\appdata\local\programs\python\python38\lib\site-packages (1.5.1)
# You should consider upgrading via the 'c:\users\negar\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
# load training and test set
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
cifar10_training_set = torchvision.datasets.CIFAR10(root='./dataset_CIFAR10', train=True, transform=image_transforms,
                                                    download=True)
cifar10_test_set = torchvision.datasets.CIFAR10(root='./dataset_CIFAR10', train=False, transform=image_transforms,
                                                    download=True)
trainingset_loader = datautils.DataLoader(dataset=cifar10_training_set, batch_size=4, shuffle=True, num_workers=2)
testset_loader = datautils.DataLoader(dataset=cifar10_test_set, batch_size=4, shuffle=True, num_workers=2)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
def matplotlib_imshow(img_tensor, title=None):
    """
    Get and image in tensor form and display it.
    :param img_tensor:
    :return:
    """
    device = torch.device("cpu")
    img_tensor_cpu = img_tensor.to(device)
 
    std = 0.5
    mean = 0.5
 
    img_tensor = std * img_tensor_cpu + mean
    # convert tensor to numpy
    img = img_tensor.numpy()
    # in pytorch image is (3, H, W)
    # normal form is (H, W, 3)
    img = img.transpose(1, 2, 0)
    plt.figure()
    plt.imshow(img)
    if title is not None:
        plt.title(title)

# %%
class ConvNet(to_nn.Module):
 
    # constructor of model
    def __init__(self):
        # constructor of parent class
        super(ConvNet, self).__init__()
        # learnable parameter of model (convolution and fully connected layers)
        self.conv1 = to_nn.Conv2d(in_channels=3, out_channels=9, kernel_size=(5, 5))
        self.conv2 = to_nn.Conv2d(in_channels=9, out_channels=18, kernel_size=(3, 3))
        self.fc1 = to_nn.Linear(in_features=18 * 6 * 6, out_features=100)
        self.fc2 = to_nn.Linear(in_features=100, out_features=40)
        self.fc3 = to_nn.Linear(in_features=40, out_features=10)
 
    # feedforward
    def forward(self, input):
        # convolutional layer 1
        out = self.conv1(input)
        # pooling kernel size(2,2) and relu non linearity
        out = to_f.max_pool2d(to_f.relu(out), (2, 2))
        # convolutional layer 2
        out = self.conv2(out)
        # pooling kernel size(2,2) and relu non linearity
        out = to_f.max_pool2d(to_f.relu(out), (2, 2))
        # flatten
        out = out.view(-1, 18 * 6 * 6)
        # fully connected 1 with relu non linearity
        out = to_f.relu(self.fc1(out))
        # fully connected 2 with relu non linearity
        out = to_f.relu(self.fc2(out))
        # fully connected 3
        out = self.fc3(out)
        return out

# %%
net = ConvNet()

# %%
criterion = to_nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

# %% [markdown]
# # L1 Regularization

# %%
LAMBDA = 0.009

for epoch in range(10):
 
    # loss of epoch
    running_loss = 0.0
 
    # iterate over all batches
    for i, data in enumerate(trainingset_loader, 0):
 
        images, labels = data
 
        # makes all gradients zero
        optimizer.zero_grad()
 
        # feedforward
        images = images
        output = net(images)
 
        # loss
        labels = labels
        loss = criterion(output, labels)
        
        #L1 regularization
        
        l1_regularization = torch.tensor(0).long()
        for param in net.parameters():
            l1_regularization += torch.norm(param, 1).long()
            
        loss += LAMBDA * l1_regularization
        
        
 
        # backpropagation
        loss.backward()
 
        # update parameters
        optimizer.step()
 
        running_loss += loss.item()
 
        if i % 1000 == 999:
            print('epoch {}, mini-batch {}, loss {}'.format(epoch, i + 1, running_loss/1000.0))
            running_loss = 0.0
 
print('Training Phase is done.')
# Out:
# epoch 0, mini-batch 1000, loss 16.87395444869995
# epoch 0, mini-batch 2000, loss 16.892783443450927
# epoch 0, mini-batch 3000, loss 16.978272322654725
# epoch 0, mini-batch 4000, loss 17.159476469039916
# epoch 0, mini-batch 5000, loss 17.35378352737427
# epoch 0, mini-batch 6000, loss 17.591730031967163
# epoch 0, mini-batch 7000, loss 17.853540184020996
# epoch 0, mini-batch 8000, loss 18.138197238922118
# epoch 0, mini-batch 9000, loss 18.427487554550172
# epoch 0, mini-batch 10000, loss 18.717861778259277
# epoch 0, mini-batch 11000, loss 18.981570819854735
# epoch 0, mini-batch 12000, loss 19.251259162902834
# epoch 1, mini-batch 1000, loss 19.69650212097168
# epoch 1, mini-batch 2000, loss 19.991272775650025
# epoch 1, mini-batch 3000, loss 20.311005786895752
# epoch 1, mini-batch 4000, loss 20.623729850769042
# epoch 1, mini-batch 5000, loss 20.910798871994018
# epoch 1, mini-batch 6000, loss 21.18926469039917
# epoch 1, mini-batch 7000, loss 21.484459915161132
# epoch 1, mini-batch 8000, loss 21.7417951335907
# epoch 1, mini-batch 9000, loss 22.01943007850647
# epoch 1, mini-batch 10000, loss 22.353743675231932
# epoch 1, mini-batch 11000, loss 22.626949701309204
# epoch 1, mini-batch 12000, loss 22.915407608032226
# epoch 2, mini-batch 1000, loss 23.305461153030397
# epoch 2, mini-batch 2000, loss 23.681480991363525
# epoch 2, mini-batch 3000, loss 23.98649489593506
# epoch 2, mini-batch 4000, loss 24.276770637512207
# epoch 2, mini-batch 5000, loss 24.55970185470581
# epoch 2, mini-batch 6000, loss 24.851920190811157
# epoch 2, mini-batch 7000, loss 25.121895839691163
# epoch 2, mini-batch 8000, loss 25.444435569763183
# epoch 2, mini-batch 9000, loss 25.72074807548523
# epoch 2, mini-batch 10000, loss 25.967672840118407
# epoch 2, mini-batch 11000, loss 26.21981452178955
# epoch 2, mini-batch 12000, loss 26.482175453186034
# epoch 3, mini-batch 1000, loss 26.857083824157716
# epoch 3, mini-batch 2000, loss 27.178099267959595
# epoch 3, mini-batch 3000, loss 27.48381633377075
# epoch 3, mini-batch 4000, loss 27.880324405670166
# epoch 3, mini-batch 5000, loss 28.175416473388673
# epoch 3, mini-batch 6000, loss 28.440254846572877
# epoch 3, mini-batch 7000, loss 28.758898777008056
# epoch 3, mini-batch 8000, loss 29.0415682220459
# epoch 3, mini-batch 9000, loss 29.353075021743773
# epoch 3, mini-batch 10000, loss 29.582336759567262
# epoch 3, mini-batch 11000, loss 29.855599571228026
# epoch 3, mini-batch 12000, loss 30.110151679992676
# epoch 4, mini-batch 1000, loss 30.44824426841736
# epoch 4, mini-batch 2000, loss 30.716182199478148
# epoch 4, mini-batch 3000, loss 31.05515895462036
# epoch 4, mini-batch 4000, loss 31.386118400573732
# epoch 4, mini-batch 5000, loss 31.650782678604127
# epoch 4, mini-batch 6000, loss 31.93170726394653
# epoch 4, mini-batch 7000, loss 32.203130771636964
# epoch 4, mini-batch 8000, loss 32.45366073417664
# epoch 4, mini-batch 9000, loss 32.725360591888425
# epoch 4, mini-batch 10000, loss 32.92420766067505
# epoch 4, mini-batch 11000, loss 33.15806887054443
# epoch 4, mini-batch 12000, loss 33.4035737953186
# epoch 5, mini-batch 1000, loss 33.704891284942626
# epoch 5, mini-batch 2000, loss 34.02449864578247
# epoch 5, mini-batch 3000, loss 34.30299390792847
# epoch 5, mini-batch 4000, loss 34.64952602005005
# epoch 5, mini-batch 5000, loss 34.96127040481567
# epoch 5, mini-batch 6000, loss 35.192362804412845
# epoch 5, mini-batch 7000, loss 35.44842002487183
# epoch 5, mini-batch 8000, loss 35.69778396987915
# epoch 5, mini-batch 9000, loss 35.97424505996704
# epoch 5, mini-batch 10000, loss 36.19172037124634
# epoch 5, mini-batch 11000, loss 36.40955347442627
# epoch 5, mini-batch 12000, loss 36.686987335205075
# epoch 6, mini-batch 1000, loss 36.92877236175537
# epoch 6, mini-batch 2000, loss 37.258558013916016
# epoch 6, mini-batch 3000, loss 37.50777715682983
# epoch 6, mini-batch 4000, loss 37.815707389831545
# epoch 6, mini-batch 5000, loss 38.06931126785278
# epoch 6, mini-batch 6000, loss 38.32727753829956
# epoch 6, mini-batch 7000, loss 38.58043201828003
# epoch 6, mini-batch 8000, loss 38.836825740814206
# epoch 6, mini-batch 9000, loss 39.088115253448485
# epoch 6, mini-batch 10000, loss 39.301553073883056
# epoch 6, mini-batch 11000, loss 39.569608192443845
# epoch 6, mini-batch 12000, loss 39.76353623199463
# epoch 7, mini-batch 1000, loss 40.05141753768921
# epoch 7, mini-batch 2000, loss 40.301634353637695
# epoch 7, mini-batch 3000, loss 40.571133266448975
# epoch 7, mini-batch 4000, loss 40.857973690032956
# epoch 7, mini-batch 5000, loss 41.13618267440796
# epoch 7, mini-batch 6000, loss 41.37160959625244
# epoch 7, mini-batch 7000, loss 41.638523750305175
# epoch 7, mini-batch 8000, loss 41.86794784164429
# epoch 7, mini-batch 9000, loss 42.128445030212404
# epoch 7, mini-batch 10000, loss 42.32005669784546
# epoch 7, mini-batch 11000, loss 42.560932720184326
# epoch 7, mini-batch 12000, loss 42.72456736373901
# epoch 8, mini-batch 1000, loss 42.9588938407898
# epoch 8, mini-batch 2000, loss 43.24835655593872
# epoch 8, mini-batch 3000, loss 43.51590464782715
# epoch 8, mini-batch 4000, loss 43.76272789764404
# epoch 8, mini-batch 5000, loss 44.05367498016357
# epoch 8, mini-batch 6000, loss 44.324346256256106
# epoch 8, mini-batch 7000, loss 44.52895464324951
# epoch 8, mini-batch 8000, loss 44.76864181137085
# epoch 8, mini-batch 9000, loss 44.98183288192749
# epoch 8, mini-batch 10000, loss 45.19011616134644
# epoch 8, mini-batch 11000, loss 45.410508338928224
# epoch 8, mini-batch 12000, loss 45.63428269195557
# epoch 9, mini-batch 1000, loss 45.867580505371095
# epoch 9, mini-batch 2000, loss 46.14574457168579
# epoch 9, mini-batch 3000, loss 46.430232074737546
# epoch 9, mini-batch 4000, loss 46.69522271347046
# epoch 9, mini-batch 5000, loss 46.925535125732424
# epoch 9, mini-batch 6000, loss 47.10027200317383
# epoch 9, mini-batch 7000, loss 47.32697375869751
# epoch 9, mini-batch 8000, loss 47.52257042312622
# epoch 9, mini-batch 9000, loss 47.74914581298828
# epoch 9, mini-batch 10000, loss 47.97162823867798
# epoch 9, mini-batch 11000, loss 48.16234234237671
# epoch 9, mini-batch 12000, loss 48.37818142318726
# Training Phase is done.

# %%
# show qualitative result of training
data_iter = iter(testset_loader)
for i in range(3):
    images, labels_ground_truth = data_iter.next()
    images = images
    labels_ground_truth = labels_ground_truth
    outputs = net(images)
    _, predicted = torch.max(outputs, dim=1)
    matplotlib_imshow(img_tensor=torchvision.utils.make_grid(images), title=['predicted: '+classes[i.item()] for i in predicted])

correct = 0
total = 0
with torch.no_grad():
    for data in testset_loader:
        images, ground_truth_labels = data
        images = images
        ground_truth_labels = ground_truth_labels
        outputs = net(images)
        _, predicted = torch.max(outputs, dim=1)
        total += ground_truth_labels.size(0)
        correct += (ground_truth_labels==predicted).sum().item()
print('Accuracy on test set is: {}%'.format(correct/total * 100))
 
# accuracy of each class in test set
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in testset_loader:
        images, labels = data
        images = images
        labels = labels
        outputs = net(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1
for i in range(10):
    print('Accuracy of {}: {}%'.format(classes[i], 100 * class_correct[i] / class_total[i]))
plt.show()
# Out:
# Accuracy on test set is: 66.84%
# Accuracy of plane: 68.0%
# Accuracy of car: 82.9%
# Accuracy of bird: 57.4%
# Accuracy of cat: 35.7%
# Accuracy of deer: 65.8%
# Accuracy of dog: 62.7%
# Accuracy of frog: 74.2%
# Accuracy of horse: 68.9%
# Accuracy of ship: 76.3%
# Accuracy of truck: 76.5%

# %% [markdown]
# # L2 Regularization

# %%
LAMBDA = 0.009

for epoch in range(10):
 
    # loss of epoch
    running_loss = 0.0
 
    # iterate over all batches
    for i, data in enumerate(trainingset_loader, 0):
 
        images, labels = data
 
        # makes all gradients zero
        optimizer.zero_grad()
 
        # feedforward
        images = images
        output = net(images)
 
        # loss
        labels = labels
        loss = criterion(output, labels)
        
        #L1 regularization
        
        l2_regularization = torch.tensor(0).long()
        for param in net.parameters():
            l2_regularization += torch.norm(param, 1).long()
            
        loss += LAMBDA * l2_regularization
        
        
 
        # backpropagation
        loss.backward()
 
        # update parameters
        optimizer.step()
 
        running_loss += loss.item()
 
        if i % 1000 == 999:
            print('epoch {}, mini-batch {}, loss {}'.format(epoch, i + 1, running_loss/1000.0))
            running_loss = 0.0
 
print('Training Phase is done.')
# Out:
# epoch 0, mini-batch 1000, loss 48.60926276397705
# epoch 0, mini-batch 2000, loss 48.87651376724243
# epoch 0, mini-batch 3000, loss 49.120163627624514
# epoch 0, mini-batch 4000, loss 49.35712122344971
# epoch 0, mini-batch 5000, loss 49.59969129562378
# epoch 0, mini-batch 6000, loss 49.849020366668704
# epoch 0, mini-batch 7000, loss 50.06390543746948
# epoch 0, mini-batch 8000, loss 50.26813953781128
# epoch 0, mini-batch 9000, loss 50.47772659683228
# epoch 0, mini-batch 10000, loss 50.721739208221436
# epoch 0, mini-batch 11000, loss 50.900181175231936
# epoch 0, mini-batch 12000, loss 51.068987350463864
# epoch 1, mini-batch 1000, loss 51.28232724380493
# epoch 1, mini-batch 2000, loss 51.53848588180542
# epoch 1, mini-batch 3000, loss 51.80307726287842
# epoch 1, mini-batch 4000, loss 52.04590534210205
# epoch 1, mini-batch 5000, loss 52.26241048431397
# epoch 1, mini-batch 6000, loss 52.489200736999514
# epoch 1, mini-batch 7000, loss 52.714004123687744
# epoch 1, mini-batch 8000, loss 52.9593032875061
# epoch 1, mini-batch 9000, loss 53.14262000656128
# epoch 1, mini-batch 10000, loss 53.31337076187134
# epoch 1, mini-batch 11000, loss 53.5836794090271
# epoch 1, mini-batch 12000, loss 53.722947219848635
# epoch 2, mini-batch 1000, loss 53.926757221221926
# epoch 2, mini-batch 2000, loss 54.18035733795166
# epoch 2, mini-batch 3000, loss 54.384918800354
# epoch 2, mini-batch 4000, loss 54.64360692214966
# epoch 2, mini-batch 5000, loss 54.82166105651856
# epoch 2, mini-batch 6000, loss 55.05166758728027
# epoch 2, mini-batch 7000, loss 55.282104873657225
# epoch 2, mini-batch 8000, loss 55.46642640304565
# epoch 2, mini-batch 9000, loss 55.70490259552002
# epoch 2, mini-batch 10000, loss 55.922618186950686
# epoch 2, mini-batch 11000, loss 56.07609650421143
# epoch 2, mini-batch 12000, loss 56.248425952911376
# epoch 3, mini-batch 1000, loss 56.39819499206543
# epoch 3, mini-batch 2000, loss 56.67785705947876
# epoch 3, mini-batch 3000, loss 56.88665757369995
# epoch 3, mini-batch 4000, loss 57.10754014205933
# epoch 3, mini-batch 5000, loss 57.35824451828003
# epoch 3, mini-batch 6000, loss 57.55846326828003
# epoch 3, mini-batch 7000, loss 57.7649949836731
# epoch 3, mini-batch 8000, loss 57.95127871704101
# epoch 3, mini-batch 9000, loss 58.14042467498779
# epoch 3, mini-batch 10000, loss 58.362226627349855
# epoch 3, mini-batch 11000, loss 58.55474110412597
# epoch 3, mini-batch 12000, loss 58.72082565689087
# epoch 4, mini-batch 1000, loss 58.872982662200926
# epoch 4, mini-batch 2000, loss 59.047374195098875
# epoch 4, mini-batch 3000, loss 59.27440688705445
# epoch 4, mini-batch 4000, loss 59.523484886169435
# epoch 4, mini-batch 5000, loss 59.759271018981934
# epoch 4, mini-batch 6000, loss 59.93308492279053
# epoch 4, mini-batch 7000, loss 60.17977836608887
# epoch 4, mini-batch 8000, loss 60.346830959320066
# epoch 4, mini-batch 9000, loss 60.52631561279297
# epoch 4, mini-batch 10000, loss 60.68091256713867
# epoch 4, mini-batch 11000, loss 60.84584115219116
# epoch 4, mini-batch 12000, loss 61.10942776107788
# epoch 5, mini-batch 1000, loss 61.276913261413576
# epoch 5, mini-batch 2000, loss 61.49088750839233
# epoch 5, mini-batch 3000, loss 61.714864147186276
# epoch 5, mini-batch 4000, loss 61.89704908370972
# epoch 5, mini-batch 5000, loss 62.06796817016602
# epoch 5, mini-batch 6000, loss 62.289890132904056
# epoch 5, mini-batch 7000, loss 62.45577006530762
# epoch 5, mini-batch 8000, loss 62.6561821975708
# epoch 5, mini-batch 9000, loss 62.84188103103638
# epoch 5, mini-batch 10000, loss 62.97753021621704
# epoch 5, mini-batch 11000, loss 63.22236121749878
# epoch 5, mini-batch 12000, loss 63.41561110687256
# epoch 6, mini-batch 1000, loss 63.5280923576355
# epoch 6, mini-batch 2000, loss 63.779238052368164
# epoch 6, mini-batch 3000, loss 63.97370267868042
# epoch 6, mini-batch 4000, loss 64.19947867202758
# epoch 6, mini-batch 5000, loss 64.39166188049316
# epoch 6, mini-batch 6000, loss 64.5157392654419
# epoch 6, mini-batch 7000, loss 64.72504438781738
# epoch 6, mini-batch 8000, loss 64.89814963531494
# epoch 6, mini-batch 9000, loss 65.13045989227295
# epoch 6, mini-batch 10000, loss 65.29294694519044
# epoch 6, mini-batch 11000, loss 65.4583537902832
# epoch 6, mini-batch 12000, loss 65.64723978424072
# epoch 7, mini-batch 1000, loss 65.80505000305176
# epoch 7, mini-batch 2000, loss 66.01209134674072
# epoch 7, mini-batch 3000, loss 66.21268215942384
# epoch 7, mini-batch 4000, loss 66.38007578277588
# epoch 7, mini-batch 5000, loss 66.59052199554444
# epoch 7, mini-batch 6000, loss 66.7392899093628
# epoch 7, mini-batch 7000, loss 66.98124591827393
# epoch 7, mini-batch 8000, loss 67.14518368530274
# epoch 7, mini-batch 9000, loss 67.25681313323975
# epoch 7, mini-batch 10000, loss 67.4907027053833
# epoch 7, mini-batch 11000, loss 67.63921536254882
# epoch 7, mini-batch 12000, loss 67.80830228424072
# epoch 8, mini-batch 1000, loss 67.9657643508911
# epoch 8, mini-batch 2000, loss 68.20366455078126
# epoch 8, mini-batch 3000, loss 68.4000083770752
# epoch 8, mini-batch 4000, loss 68.58853881835938
# epoch 8, mini-batch 5000, loss 68.83154078674316
# epoch 8, mini-batch 6000, loss 69.01995426940918
# epoch 8, mini-batch 7000, loss 69.23315303802491
# epoch 8, mini-batch 8000, loss 69.39919570922852
# epoch 8, mini-batch 9000, loss 69.56727278900146
# epoch 8, mini-batch 10000, loss 69.72145719909668
# epoch 8, mini-batch 11000, loss 69.89234967041016
# epoch 8, mini-batch 12000, loss 70.03143576049804
# epoch 9, mini-batch 1000, loss 70.2019334640503
# epoch 9, mini-batch 2000, loss 70.38876522827148
# epoch 9, mini-batch 3000, loss 70.59735820007324
# epoch 9, mini-batch 4000, loss 70.76078053283692
# epoch 9, mini-batch 5000, loss 70.96861178588867
# epoch 9, mini-batch 6000, loss 71.17259942626953
# epoch 9, mini-batch 7000, loss 71.30452828216552
# epoch 9, mini-batch 8000, loss 71.44991904449464
# epoch 9, mini-batch 9000, loss 71.60971334075927
# epoch 9, mini-batch 10000, loss 71.79128336334229
# epoch 9, mini-batch 11000, loss 71.93096910858154
# epoch 9, mini-batch 12000, loss 72.12527096557618
# Training Phase is done.

# %%
# show qualitative result of training
data_iter = iter(testset_loader)
for i in range(3):
    images, labels_ground_truth = data_iter.next()
    images = images
    labels_ground_truth = labels_ground_truth
    outputs = net(images)
    _, predicted = torch.max(outputs, dim=1)
    matplotlib_imshow(img_tensor=torchvision.utils.make_grid(images), title=['predicted: '+classes[i.item()] for i in predicted])

correct = 0
total = 0
with torch.no_grad():
    for data in testset_loader:
        images, ground_truth_labels = data
        images = images
        ground_truth_labels = ground_truth_labels
        outputs = net(images)
        _, predicted = torch.max(outputs, dim=1)
        total += ground_truth_labels.size(0)
        correct += (ground_truth_labels==predicted).sum().item()
print('Accuracy on test set is: {}%'.format(correct/total * 100))
 
# accuracy of each class in test set
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in testset_loader:
        images, labels = data
        images = images
        labels = labels
        outputs = net(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1
for i in range(10):
    print('Accuracy of {}: {}%'.format(classes[i], 100 * class_correct[i] / class_total[i]))
plt.show()
# Out:
# Accuracy on test set is: 64.91%
# Accuracy of plane: 75.6%
# Accuracy of car: 81.4%
# Accuracy of bird: 52.3%
# Accuracy of cat: 37.4%
# Accuracy of deer: 60.6%
# Accuracy of dog: 61.2%
# Accuracy of frog: 70.7%
# Accuracy of horse: 73.4%
# Accuracy of ship: 67.8%
# Accuracy of truck: 68.7%
